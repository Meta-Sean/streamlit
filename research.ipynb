# %%
import pandas as pd
def load_data():
    url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
    html = pd.read_html(url, header = 0)
    df = html[0]
    return df

# %%
df = load_data()
df
# Out:
#     Symbol              Security SEC filings             GICS Sector  \
# 0      MMM                    3M     reports             Industrials
# 1      AOS           A. O. Smith     reports             Industrials
# 2      ABT                Abbott     reports             Health Care
# 3     ABBV                AbbVie     reports             Health Care
# 4     ABMD               Abiomed     reports             Health Care
# ..     ...                   ...         ...                     ...
# 498    YUM           Yum! Brands     reports  Consumer Discretionary
# 499   ZBRA    Zebra Technologies     reports  Information Technology
# 500    ZBH         Zimmer Biomet     reports             Health Care
# 501   ZION  Zions Bancorporation     reports              Financials
# 502    ZTS                Zoetis     reports             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota
# 1                     Building Products     Milwaukee, Wisconsin
# 2                 Health Care Equipment  North Chicago, Illinois
# 3                       Pharmaceuticals  North Chicago, Illinois
# 4                 Health Care Equipment   Danvers, Massachusetts
# ..                                  ...                      ...
# 498                         Restaurants     Louisville, Kentucky
# 499  Electronic Equipment & Instruments   Lincolnshire, Illinois
# 500               Health Care Equipment          Warsaw, Indiana
# 501                      Regional Banks     Salt Lake City, Utah
# 502                     Pharmaceuticals   Parsippany, New Jersey
#
#     Date first added      CIK      Founded
# 0         1976-08-09    66740         1902
# 1         2017-07-26    91142         1916
# 2         1964-03-31     1800         1888
# 3         2012-12-31  1551152  2013 (1888)
# 4         2018-05-31   815094         1981
# ..               ...      ...          ...
# 498       1997-10-06  1041061         1997
# 499       2019-12-23   877212         1969
# 500       2001-08-07  1136869         1927
# 501       2001-06-22   109380         1873
# 502       2013-06-21  1555280         1952
#
# [503 rows x 9 columns]

# %%
sector = df.groupby('GICS Sector')

# %%
sector.first()
# Out:
#                        Symbol                         Security SEC filings  \
# GICS Sector
# Communication Services   ATVI              Activision Blizzard     reports
# Consumer Discretionary    AAP               Advance Auto Parts     reports
# Consumer Staples          ADM                              ADM     reports
# Energy                    APA                  APA Corporation     reports
# Financials                AFL                            Aflac     reports
# Health Care               ABT                           Abbott     reports
# Industrials               MMM                               3M     reports
# Information Technology    ACN                        Accenture     reports
# Materials                 APD       Air Products and Chemicals     reports
# Real Estate               ARE  Alexandria Real Estate Equities     reports
# Utilities                 AES                  AES Corporation     reports
#
#                                                    GICS Sub-Industry  \
# GICS Sector
# Communication Services                Interactive Home Entertainment
# Consumer Discretionary                             Automotive Retail
# Consumer Staples                               Agricultural Products
# Energy                            Oil & Gas Exploration & Production
# Financials                                   Life & Health Insurance
# Health Care                                    Health Care Equipment
# Industrials                                 Industrial Conglomerates
# Information Technology                IT Consulting & Other Services
# Materials                                           Industrial Gases
# Real Estate                                             Office REITs
# Utilities               Independent Power Producers & Energy Traders
#
#                            Headquarters Location Date first added      CIK  \
# GICS Sector
# Communication Services  Santa Monica, California       2015-08-31   718877
# Consumer Discretionary   Raleigh, North Carolina       2015-07-09  1158449
# Consumer Staples               Chicago, Illinois       1981-07-29     7084
# Energy                            Houston, Texas       1997-07-28  1841666
# Financials                     Columbus, Georgia       1999-05-28     4977
# Health Care              North Chicago, Illinois       1964-03-31     1800
# Industrials                Saint Paul, Minnesota       1976-08-09    66740
# Information Technology           Dublin, Ireland       2011-07-06  1467373
# Materials                Allentown, Pennsylvania       1985-04-30     2969
# Real Estate                 Pasadena, California       2017-03-20  1035443
# Utilities                    Arlington, Virginia       1998-10-02   874761
#
#                        Founded
# GICS Sector
# Communication Services    2008
# Consumer Discretionary    1932
# Consumer Staples          1902
# Energy                    1954
# Financials                1955
# Health Care               1888
# Industrials               1902
# Information Technology    1989
# Materials                 1940
# Real Estate               1994
# Utilities                 1981

# %%
sector.describe()
# Out:
#                          CIK                                                   \
#                        count          mean            std      min        25%
# GICS Sector
# Communication Services  26.0  1.094660e+06  521922.541174  18926.0  752994.75
# Consumer Discretionary  56.0  8.620841e+05  454741.225170  27419.0  759791.50
# Consumer Staples        33.0  4.185174e+05  583783.310585   7084.0   24545.00
# Energy                  23.0  8.423255e+05  640873.249366   4447.0   97594.00
# Financials              66.0  6.369112e+05  537329.687765   4962.0   71386.25
# Health Care             64.0  8.222880e+05  531850.572835   1800.0  312903.00
# Industrials             71.0  6.586874e+05  585071.338713   4281.0   76847.00
# Information Technology  75.0  9.231303e+05  507556.024985   2488.0  759324.00
# Materials               28.0  8.369064e+05  699182.236462   2969.0   67840.25
# Real Estate             31.0  9.513509e+05  373448.241959  34903.0  889395.00
# Utilities               30.0  8.457124e+05  460276.348204   4904.0  737178.50
#
#
#                               50%         75%        max
# GICS Sector
# Communication Services  1129179.0  1532807.75  1754301.0
# Consumer Discretionary   918562.5  1130953.25  1590895.0
# Consumer Staples          77476.0   865752.00  1679273.0
# Energy                  1035002.0  1447738.50  1841666.0
# Financials               739974.5  1118437.00  1601712.0
# Health Care              880632.0  1100020.50  1821825.0
# Industrials              728535.0  1058871.50  1783180.0
# Information Technology  1002047.0  1346724.50  1730168.0
# Materials                915994.5  1419355.00  1755672.0
# Real Estate             1020569.0  1067255.50  1705696.0
# Utilities                898492.5  1043948.50  1868275.0

# %%
sector.get_group('Health Care')
# Out:
#     Symbol                      Security SEC filings  GICS Sector  \
# 2      ABT                        Abbott     reports  Health Care
# 3     ABBV                        AbbVie     reports  Health Care
# 4     ABMD                       Abiomed     reports  Health Care
# 13       A          Agilent Technologies     reports  Health Care
# 19    ALGN              Align Technology     reports  Health Care
# ..     ...                           ...         ...          ...
# 473   VTRS                       Viatris     reports  Health Care
# 483    WAT            Waters Corporation     reports  Health Care
# 487    WST  West Pharmaceutical Services     reports  Health Care
# 500    ZBH                 Zimmer Biomet     reports  Health Care
# 502    ZTS                        Zoetis     reports  Health Care
#
#             GICS Sub-Industry     Headquarters Location Date first added  \
# 2       Health Care Equipment   North Chicago, Illinois       1964-03-31
# 3             Pharmaceuticals   North Chicago, Illinois       2012-12-31
# 4       Health Care Equipment    Danvers, Massachusetts       2018-05-31
# 13      Health Care Equipment   Santa Clara, California       2000-06-05
# 19       Health Care Supplies            Tempe, Arizona       2017-06-19
# ..                        ...                       ...              ...
# 473           Pharmaceuticals  Pittsburgh, Pennsylvania       2004-04-23
# 483  Health Care Distributors    Milford, Massachusetts              NaN
# 487      Health Care Supplies       Exton, Pennsylvania       2020-05-22
# 500     Health Care Equipment           Warsaw, Indiana       2001-08-07
# 502           Pharmaceuticals    Parsippany, New Jersey       2013-06-21
#
#          CIK      Founded
# 2       1800         1888
# 3    1551152  2013 (1888)
# 4     815094         1981
# 13   1090872         1999
# 19   1097149         1997
# ..       ...          ...
# 473  1792044         1961
# 483  1000697         1958
# 487   105770         1923
# 500  1136869         1927
# 502  1555280         1952
#
# [64 rows x 9 columns]

# %%
import yfinance as yf

# %%
df_selected_sector = sector.get_group('Health Care')

# %%
data = yf.download(
        tickers = list(df_selected_sector[:10].Symbol),
        period = "ytd",
        interval = "1d",
        group_by = 'ticker',
        auto_adjust = True,
        prepost = True,
        threads = True,
        proxy = None
    )
# Out:
# [*********************100%***********************]  10 of 10 completed

# %%
df = pd.DataFrame(data['ABT'].Close)
df['Date'] = df.index
df
# Out:
#                                 Close                      Date
# Date
# 2022-01-03 00:00:00-05:00  136.745361 2022-01-03 00:00:00-05:00
# 2022-01-04 00:00:00-05:00  133.529343 2022-01-04 00:00:00-05:00
# 2022-01-05 00:00:00-05:00  132.929398 2022-01-05 00:00:00-05:00
# 2022-01-06 00:00:00-05:00  132.909729 2022-01-06 00:00:00-05:00
# 2022-01-07 00:00:00-05:00  133.322800 2022-01-07 00:00:00-05:00
# ...                               ...                       ...
# 2022-10-10 00:00:00-04:00  100.655067 2022-10-10 00:00:00-04:00
# 2022-10-11 00:00:00-04:00  101.272156 2022-10-11 00:00:00-04:00
# 2022-10-12 00:00:00-04:00   99.610001 2022-10-12 00:00:00-04:00
# 2022-10-13 00:00:00-04:00  102.470001 2022-10-13 00:00:00-04:00
# 2022-10-14 00:00:00-04:00  100.910004 2022-10-14 00:00:00-04:00
#
# [198 rows x 2 columns]

# %%
# Plot Closing Price of Query Symbol
def price_plot(symbol):
  df = pd.DataFrame(data[symbol].Close)
  df['Date'] = df.index
  plt.fill_between(df.Date, df.Close, color='skyblue', alpha=0.3)
  plt.plot(df.Date, df.Close, color='skyblue', alpha=0.8)
  plt.xticks(rotation=90)
  plt.title(symbol, fontweight='bold')
  plt.xlabel('Date', fontweight='bold')
  plt.ylabel('Closing Price', fontweight='bold')
  return plt.show()

# %%
price_plot('ABT')
